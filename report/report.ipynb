# %% [markdown]
# # Report

# %% [markdown]
# Recommender-System Report

# %%
import sys
import pandas as pd
sys.path.insert(0, '../data')
from DA import DA

# %%
data = pd.read_csv('../data/Recommender4Retail.csv', nrows=1000)
data
# Out:
#      Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0             1   2539329        1    prior             1          2
# 1             2   2539329        1    prior             1          2
# 2             3   2539329        1    prior             1          2
# 3             4   2539329        1    prior             1          2
# 4             5   2539329        1    prior             1          2
# 5             6   2398795        1    prior             2          3
# 6             7   2398795        1    prior             2          3
# 7             8   2398795        1    prior             2          3
# 8             9   2398795        1    prior             2          3
# 9            10   2398795        1    prior             2          3
# 10           11   2398795        1    prior             2          3
# 11           12    473747        1    prior             3          3
# 12           13    473747        1    prior             3          3
# ...
