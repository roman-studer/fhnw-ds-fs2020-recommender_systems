# %% [markdown]
# # Report

# %% [markdown]
# Recommender-System Report

# %% [markdown]
# ## Introduction
# <span style="color: red;">TODO: Explain purpose of document</span>

# %%
import sys
import pandas as pd
sys.path.insert(0, '../data')
from DA import DA

# %%
# visit https://github.com/roman-studer/fhnw-ds-fs2020-recommender_systems/blob/master/README.md for a description of the columns

data = pd.read_csv('../data/Recommender4Retail.csv', nrows=10) # nrows= limits the loaded rows

data = data[data.columns[1:]] #drop csv-index
data.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  \
# ...
